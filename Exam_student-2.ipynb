# %% [markdown]
# # Exam R
# Mark Klik & Misja Mikkers
#
# # Introduction
#
# The exam consists of 2 parts. In the first part, you have to run a regression, test if the assumptions of a linear regression model are met, and make 2 graphs.
#
# In the second part of the exam, you will have to make a map of Catholic and Protestant schools in the Netherlands.
#
# # Packages

# %%
library(tidyverse)
library(gvlma)

# %% [markdown]
# # Assignment 1
#
#
# ## Data
#
# The data are given:

# %%
set.seed(123)
df1 <- as.data.frame(matrix(runif(1*50, min = 1, max = 10), ncol = 1)) %>%
    mutate(epsilon = rnorm(50, mean = 0, sd = 2)) %>%
    mutate(response = 3 - 2* V1  + epsilon) %>%
    mutate(group = ifelse(V1 <= 5, 1,2))

# %% [markdown]
# ## Asignment 1a
#
# The first assigment is to make boxplot using ggplot with group on the x-axis and V1 on the y-axis.

# %%
ggplot (df1, aes(x = factor(group), y = V1)) + geom_boxplot() + labs(x="group", y="V1")
# Out:
# plot without title

# %% [markdown]
# ## Assignment 1b
#
# Run a regression with response variable as a function of V1.
# Show the summary statistics of the regression.

# %%
reg1 <- lm(data = df1, response ~ V1)

summary(reg1)
# Out:
# Call:
# lm(formula = response ~ V1, data = df1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.5116 -1.1157 -0.1313  1.0985  4.3723
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.6305     0.6347   4.145 0.000138 ***
# V1           -1.9152     0.1014 -18.880  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.881 on 48 degrees of freedom
# Multiple R-squared:  0.8813,	Adjusted R-squared:  0.8788
# F-statistic: 356.4 on 1 and 48 DF,  p-value: < 2.2e-16

# %% [markdown]
# check if the assumptions of linear regression are met with the `gvlma()` function.

# %%
gvlma(reg1)
# Out:
# Call:
# lm(formula = response ~ V1, data = df1)
#
# Coefficients:
# (Intercept)           V1
#       2.630       -1.915
#
#
# ASSESSMENT OF THE LINEAR MODEL ASSUMPTIONS
# USING THE GLOBAL TEST ON 4 DEGREES-OF-FREEDOM:
# Level of Significance =  0.05
#
# Call:
#  gvlma(x = reg1)
#
#                       Value p-value                Decision
# Global Stat        0.654319  0.9568 Assumptions acceptable.
# Skewness           0.002398  0.9609 Assumptions acceptable.
# Kurtosis           0.007200  0.9324 Assumptions acceptable.
# Link Function      0.005852  0.9390 Assumptions acceptable.
# Heteroscedasticity 0.638869  0.4241 Assumptions acceptable.

# %% [markdown]
# ## Assignment 1c
#
# Make a scatterplot with:
# * V1 on the x-axis and the response on the y-axis
# * Include the regression line in red with confidence interval
# * In a classic theme
# * The x-axis should be labeled "Predictor", the y-axis should be labeled ("Response")

# %%
ggplot(df1, aes(x = V1, y = response)) + geom_point() + theme_classic() + geom_smooth(method = "lm", colour = 'red') + ylab('Response') + xlab('Pedictor')
# Out:
# plot without title

# %% [markdown]
# # Assigment 2
#
# # Packages

# %%
library(thematicmaps)
library(tidyverse)

# %% [markdown]
# ## Assignment 2a
#
# First you have to read in the file "nld_municipal_map.csv".
# Hint: Look at the notebook of week 6 about maps.

# %%
map_municipal <- read.csv2("../Sourcedata/nld_municipal_map.csv", stringsAsFactors = FALSE, dec = ".")
head(map_municipal)
# Out:
#   name       id x        y        order hole  piece group
# 1 Appingedam 0  251260.5 594393.8 1     FALSE 1     0.1
# 2 Appingedam 0  251427.8 594486.7 2     FALSE 1     0.1
# 3 Appingedam 0  251668.8 594646.8 3     FALSE 1     0.1
# 4 Appingedam 0  251713.5 594770.9 4     FALSE 1     0.1
# 5 Appingedam 0  251354.6 595461.4 5     FALSE 1     0.1
# 6 Appingedam 0  251310.3 596022.5 6     FALSE 1     0.1

# %% [markdown]
# ## Assignment 2b
#
# Now you can make an empty map of the Netherlands.

# %%
AddMapLayer(MapPlot(), map_municipal)
# Out:
# plot without title

# %% [markdown]
# ## Assignment 2c
#
# Read in the pc4 locations (nld_pc4_locations.csv).
#
# Hint: Don't forget the X and Y should be numeric variables!

# %%
pc4_locations <- read.csv2("../Sourcedata/nld_pc4_locations.csv")%>%
  mutate(X = as.numeric(as.character(X))) %>%
   mutate(Y = as.numeric(as.character(Y)))

str(pc4_locations)
# Out:
# 'data.frame':	4066 obs. of  3 variables:
#  $ PC4: int  1011 1012 1013 1014 1015 1016 1017 1018 1019 1021 ...
#  $ X  : num  122244 121613 120325 119515 120740 ...
#  $ Y  : num  487223 487555 489672 489422 488009 ...

# %% [markdown]
# ## Assignment 2d
#
# ### 2di
#
# Read in the school data

# %%
schools <- read.csv2("../Sourcedata/schools.csv", stringsAsFactors = FALSE, dec = ".")

str(schools)
# Out:
# 'data.frame':	1603 obs. of  31 variables:
#  $ PROVINCIE                                 : chr  "                    " "Drenthe" "Drenthe" "Drenthe" ...
#  $ BEVOEGD.GEZAG.NUMMER                      : int  41152 10053 10053 13273 13273 13273 13273 13273 13273 13273 ...
#  $ BRIN.NUMMER                               : chr  "23HC" "18BR" "18BR" "20LO" ...
#  $ VESTIGINGSNUMMER                          : chr  "23HC04" "18BR00" "18BR01" "20LO00" ...
#  $ VESTIGINGSNAAM                            : chr  "RSG Lingecollege" "School voor Praktijkonderwijs Assen" "School voor Praktijkonderwijs Assen" "Openbare Scholengemeenschap Dr Nassau College voor Vwo Havo Mavo Vbo Lwoo" ...
#  $ STRAATNAAM                                : chr  "                        " "Zwartwatersweg" "Bosrand" "Mr Groen v Prinstererln" ...
#  $ HUISNUMMER.TOEVOEGING                     : chr  "            " "202" "2" "98" ...
#  $ POSTCODE                                  : chr  "       " "9406 NN" "9401 SL" "9402 KG" ...
#  $ PLAATSNAAM                                : chr  "                        " "ASSEN" "ASSEN" "ASSEN" ...
#  $ GEMEENTENUMMER                            : int  NA 106 106 106 1699 1731 1680 106 106 106 ...
#  $ GEMEENTENAAM                              : chr  "                        " "ASSEN" "ASSEN" "ASSEN" ...
#  $ DENOMINATIE                               : chr  "Openbaar" "Openbaar" "Openbaar" "Openbaar" ...
#  $ TELEFOONNUMMER                            : int  NA 592340973 NA 592333111 592675750 593538160 592261983 592333160 NA 592333160 ...
#  $ INTERNETADRES                             : chr  "                                                                                " "www.pro-assen.nl" "                                                                                " "www.dr.nassaucollege.nl" ...
#  $ ONDERWIJSSTRUCTUUR                        : chr  "VBO/MAVO" "PRO" "PRO" "VBO/HAVO/VWO" ...
#  $ STRAATNAAM.CORRESPONDENTIEADRES           : chr  "Postbus" "Zwartwatersweg" "Zwartwatersweg" "Postbus" ...
#  $ HUISNUMMER.TOEVOEGING.CORRESPONDENTIEADRES: chr  "56" "202" "202" "186" ...
#  $ POSTCODE.CORRESPONDENTIEADRES             : chr  "4000 AB" "9406 NN" "9406 NN" "9400 AD" ...
#  $ PLAATSNAAM.CORRESPONDENTIEADRES           : chr  "TIEL" "ASSEN" "ASSEN" "ASSEN" ...
#  $ NODAAL.GEBIED.CODE                        : int  NA 11 11 11 1 11 11 11 11 11 ...
#  $ NODAAL.GEBIED.NAAM                        : chr  "                        " "Assen" "Assen" "Assen" ...
#  $ RPA.GEBIED.CODE                           : int  NA 3 3 3 3 5 3 3 3 3 ...
#  $ RPA.GEBIED.NAAM                           : chr  "                        " "Centraal-Groningen" "Centraal-Groningen" "Centraal-Groningen" ...
#  $ WGR.GEBIED.CODE                           : int  NA 7 7 7 7 7 7 7 7 7 ...
#  $ WGR.GEBIED.NAAM                           : chr  "                                       " "Noord- en Midden-Drenthe" "Noord- en Midden-Drenthe" "Noord- en Midden-Drenthe" ...
#  $ COROPGEBIED.CODE                          : int  NA 7 7 7 7 7 7 7 7 7 ...
#  $ COROPGEBIED.NAAM                          : chr  "                                   " "Noord-Drenthe" "Noord-Drenthe" "Noord-Drenthe" ...
#  $ ONDERWIJSGEBIED.CODE                      : int  NA 4 4 4 1 4 4 4 4 4 ...
#  $ ONDERWIJSGEBIED.NAAM                      : chr  "                                " "Assen-Hoogeveen-Emmen" "Assen-Hoogeveen-Emmen" "Assen-Hoogeveen-Emmen" ...
#  $ RMC.REGIO.CODE                            : int  NA 7 7 7 7 7 7 7 7 7 ...
#  $ RMC.REGIO.NAAM                            : chr  "                                        " "Noord- en Midden Drenthe" "Noord- en Midden Drenthe" "Noord- en Midden Drenthe" ...

# %% [markdown]
# ### 2dii
#
# First, create a new dataframe schools1, which is equal to schools.
#
# As you see POSTCODE has a structure of (1234 AB). You should create a new variable PC4 that is equal to the first 4 numbers in POSTCODE
#
# Hint: Use the function `substr()`
#
# Then select the variables PC4 and DENOMINATIE

# %%
schools1 <- schools %>% 
            mutate(PC4 = substr(POSTCODE, 1, 4)) 

str(schools1$PC4) 
str(schools1$DENOMINATIE)
# Out:
#  chr [1:1603] "    " "9406" "9401" "9402" "9331" "9411" ...
#  chr [1:1603] "Openbaar" "Openbaar" "Openbaar" "Openbaar" ...

# %% [markdown]
# ### 2diii
#
# Create the dataframe school_loc as a join from pc4_locations and school1 that combines the columns from both data frames, but only keeps rows where the value in the pc4_locations column matches in both data frames.
# And then select the observations with DENOMINATIE is equal to "Rooms-Katholiek" or "Protestants-Christelijk"

# %%
school_loc1 <- merge(pc4_locations, schools1, by = 'PC4')
school_loc <- filter(school_loc1, DENOMINATIE == "Rooms-Katholiek" | DENOMINATIE == "Protestants-Christelijk")
school_loc
# Out:
#     PC4  X        Y        PROVINCIE     BEVOEGD.GEZAG.NUMMER BRIN.NUMMER
# 1   1065 116701.2 485645.8 Noord-Holland 41217                01TC
# 2   1071 120223.0 485571.3 Noord-Holland 40776                02AN
# 3   1077 120152.7 484262.8 Noord-Holland 41217                02AR
# 4   1077 120152.7 484262.8 Noord-Holland 40776                14SE
# 5   1081 118277.6 482449.5 Noord-Holland 41217                14VY
# 4   Beethovenplein           2                     ... 20
# 5   De Cuserstraat           3                     ... 20
# 6   Val van Urk              1                     ... 20
# 7   Heideweg                 2                     ... 20
# 8   Startbaan                3                     ... 20
# 9   Elegast                  5                     ... 20
# 10  Achterom                 152                   ... 16
# 11  Schapenkamp              200                   ... 16
# 12  Van Linschotenlaan       501                   ... 16
# 13  Peter Planciusplein      10                    ... 16
# 14  Van Linschotenlaan       503                   ... 16
# 15  Emmastraat               56-58                 ... 16
# 16  Laapersveld              9                     ... 16
# 17  Van Ghentlaan            51                    ... 16
# 18  Bisonlaan                1                     ... 16
# 19  Larenseweg               127                   ... 16
# 20  Lieven de Keylaan        58                    ... 16
# 21  Jan Blankenlaan          8                     ... 16
# 22  Langsakker               4                     ... 16
# 23  Graaf Wichman            175                   ... 16
# 24  Nieuwe 's-Gravelandseweg 38                    ... 16
# 25  Den Uyllaan              4                     ... 20
# 26  Weegbree                 55                    ... 20
# 27  Leeghwaterweg            7                     ... 20
# 28  De Keyzerstraat          1                     ... 19
# 29  Dampten                  24                    ... 19
# 30  Bouwsteen                1                     ... 19
# ... ...                      ...                       ...
# 567 Hartman Sannesstraat     5-jul                 ... 4
# 568 Hartman Sannesstraat     5                     ... 4
# 569 Birdaarderstraatweg      82                    ... 4
# 570 Rondweg-West             45                    ... 4
# 571 Woudweg                  140-A                 ... 4
# 572 Woudweg                  146                   ... 4
# 573 Parklaan                 5                     ... 4
# 574 Nijewei                  1                     ... 4
# 575 Great Sminia             38                    ... 4
# 576 De Ring                  6                     ... 4
# 577 Splitting                63                    ... 4
# 578 Raai                     200                   ... 4
# 579 Tjalling H. Haismastraat 1                     ... 4
# 580 Minnertshof              17                    ... 4
# 581 De Hoefslag              40                    ... 4
# 582 Johannes Bogermanstraat  25                    ... 4
# 583 Rodeweg                  25                    ... 3
# 584 Salland                  4                     ... 3
# 585 Selma Lagerloflaan       3                     ... 3
# 586 De Omloop                4                     ... 5
# 587 Veenhoopsweg             60                    ... 5
# 588 Erasmusweg               1                     ... 3
# 589 Multatulistraat          91                    ... 3
# 590 Admiraal de Ruyterlaan   37                    ... 3
# 591 Verzetsstrijderslaan     220                   ... 3
# 592 Heerdenpad               8                     ... 3
# 593 Kluiverboom              1                     ... 3
# 594 Diamantlaan              14                    ... 3
# 595 Reitsema Burchtstraat    4                     ... 3
# 596 Meeden                   35                    ... 1
#     RPA.GEBIED.NAAM         WGR.GEBIED.CODE WGR.GEBIED.NAAM
# 1   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 2   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 3   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 4   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 5   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 6   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 7   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 8   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 9   Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 10  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 11  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 12  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 13  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 14  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 15  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 16  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 17  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 18  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 19  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 20  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 21  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 22  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 23  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 24  Gooi en Vechtstreek     20              Gooi en Vechtstreek
# 25  Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 26  Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 27  Zuidelijk Noord-Holland 21              Agglomeratie Amsterdam
# 28  Noord-Holland-Noord     22              Westfriesland
# 29  Noord-Holland-Noord     22              Westfriesland
# 30  Noord-Holland-Noord     22              Westfriesland
# ... ...                     ...             ...
# 567 Frysl\342n              4               Friesland-Noord
# 568 Frysl\342n              4               Friesland-Noord
# 569 Frysl\342n              4               Friesland-Noord
# 570 Frysl\342n              4               Friesland-Noord
# 571 Frysl\342n              4               Friesland-Noord
# 572 Frysl\342n              4               Friesland-Noord
# 573 Frysl\342n              4               Friesland-Noord
# 574 Frysl\342n              4               Friesland-Noord
# 575 Frysl\342n              4               Friesland-Noord
# 576 Frysl\342n              6               Friesland-Oost
# 577 Frysl\342n              6               Friesland-Oost
# 578 Frysl\342n              6               Friesland-Oost
# 579 Frysl\342n              6               Friesland-Oost
# 580 Frysl\342n              6               Friesland-Oost
# 581 Frysl\342n              6               Friesland-Oost
# 582 Frysl\342n              4               Friesland-Noord
# 583 Centraal-Groningen      7               Noord- en Midden-Drenthe
# 584 Centraal-Groningen      7               Noord- en Midden-Drenthe
# 585 Centraal-Groningen      7               Noord- en Midden-Drenthe
# 586 Zuid- en Midden-Drenthe 7               Noord- en Midden-Drenthe
# 587 Zuid- en Midden-Drenthe 7               Noord- en Midden-Drenthe
# 588 Centraal-Groningen      3               Centraal en westelijk Groningen
# 589 Centraal-Groningen      3               Centraal en westelijk Groningen
# 590 Centraal-Groningen      3               Centraal en westelijk Groningen
# 591 Centraal-Groningen      3               Centraal en westelijk Groningen
# 592 Centraal-Groningen      3               Centraal en westelijk Groningen
# 593 Centraal-Groningen      3               Centraal en westelijk Groningen
# 594 Centraal-Groningen      3               Centraal en westelijk Groningen
# 595 Centraal-Groningen      3               Centraal en westelijk Groningen
# 596 Noord-Groningen         2               Noord-Groningen en Eemsmond
#     COROPGEBIED.CODE COROPGEBIED.NAAM        ONDERWIJSGEBIED.CODE
# 1   23               Groot-Amsterdam         15
# 2   23               Groot-Amsterdam         15
# 3   23               Groot-Amsterdam         15
# 4   23               Groot-Amsterdam         15
# 5   23               Groot-Amsterdam         15
# 6   23               Groot-Amsterdam         15
# 7   23               Groot-Amsterdam         15
# 8   23               Groot-Amsterdam         15
# 9   23               Groot-Amsterdam         15
# 10  24               Het Gooi en Vechtstreek 15
# 11  24               Het Gooi en Vechtstreek 15
# 12  24               Het Gooi en Vechtstreek 15
# 13  24               Het Gooi en Vechtstreek 15
# 14  24               Het Gooi en Vechtstreek 15
# 15  24               Het Gooi en Vechtstreek 15
# 16  24               Het Gooi en Vechtstreek 15
# 17  24               Het Gooi en Vechtstreek 15
# 18  24               Het Gooi en Vechtstreek 15
# 19  24               Het Gooi en Vechtstreek 15
# 20  24               Het Gooi en Vechtstreek 15
# 21  24               Het Gooi en Vechtstreek 15
# 22  24               Het Gooi en Vechtstreek 15
# 23  24               Het Gooi en Vechtstreek 15
# 24  24               Het Gooi en Vechtstreek 15
# 25  23               Groot-Amsterdam         15
# 26  23               Groot-Amsterdam         15
# 27  22               Zaanstreek              15
# 28  18               Kop van Noord-Holland   14
# 29  18               Kop van Noord-Holland   14
# 30  18               Kop van Noord-Holland   14
# ... ...              ...                     ...
# 567 4                Noord-Friesland         3
# 568 4                Noord-Friesland         3
# 569 4                Noord-Friesland         3
# 570 4                Noord-Friesland         3
# 571 4                Noord-Friesland         3
# 572 4                Noord-Friesland         3
# 573 4                Noord-Friesland         3
# 574 4                Noord-Friesland         3
# 575 4                Noord-Friesland         3
# 576 6                Zuidoost-Friesland      3
# 577 6                Zuidoost-Friesland      3
# 578 6                Zuidoost-Friesland      3
# 579 4                Noord-Friesland         3
# 580 4                Noord-Friesland         3
# 581 4                Noord-Friesland         3
# 582 4                Noord-Friesland         3
# 583 7                Noord-Drenthe           4
# 584 7                Noord-Drenthe           4
# 585 7                Noord-Drenthe           4
# 586 7                Noord-Drenthe           4
# 587 7                Noord-Drenthe           4
# 588 3                Overig Groningen        1
# 589 3                Overig Groningen        1
# 590 3                Overig Groningen        1
# 591 3                Overig Groningen        1
# 592 3                Overig Groningen        1
# 593 3                Overig Groningen        1
# 594 3                Overig Groningen        1
# 595 3                Overig Groningen        1
# 596 3                Overig Groningen        1
#     ONDERWIJSGEBIED.NAAM   RMC.REGIO.CODE RMC.REGIO.NAAM
# 1   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 2   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 3   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 4   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 5   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 6   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 7   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 8   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 9   Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 10  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 11  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 12  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 13  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 14  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 15  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 16  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 17  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 18  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 19  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 20  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 21  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 22  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 23  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 24  Zuid-Noord-Holland     20             Gooi en Vechtstreek
# 25  Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 26  Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 27  Zuid-Noord-Holland     21             Agglomeratie Amsterdam
# 28  Noord-Noord-Holland    22             West-Friesland
# 29  Noord-Noord-Holland    22             West-Friesland
# 30  Noord-Noord-Holland    22             West-Friesland
# ... ...                    ...            ...
# 567 Friesland              4              Friesland Noord
# 568 Friesland              4              Friesland Noord
# 569 Friesland              4              Friesland Noord
# 570 Friesland              4              Friesland Noord
# 571 Friesland              4              Friesland Noord
# 572 Friesland              4              Friesland Noord
# 573 Friesland              4              Friesland Noord
# 574 Friesland              4              Friesland Noord
# 575 Friesland              4              Friesland Noord
# 576 Friesland              6              Friesland-Oost ('de Friese Wouden')
# 577 Friesland              6              Friesland-Oost ('de Friese Wouden')
# 578 Friesland              6              Friesland-Oost ('de Friese Wouden')
# 579 Friesland              6              Friesland-Oost ('de Friese Wouden')
# 580 Friesland              6              Friesland-Oost ('de Friese Wouden')
# 581 Friesland              6              Friesland-Oost ('de Friese Wouden')
# 582 Friesland              4              Friesland Noord
# 583 Assen-Hoogeveen-Emmen  7              Noord- en Midden Drenthe
# 584 Assen-Hoogeveen-Emmen  7              Noord- en Midden Drenthe
# 585 Assen-Hoogeveen-Emmen  7              Noord- en Midden Drenthe
# 586 Assen-Hoogeveen-Emmen  7              Noord- en Midden Drenthe
# 587 Assen-Hoogeveen-Emmen  7              Noord- en Midden Drenthe
# 588 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 589 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 590 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 591 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 592 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 593 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 594 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 595 Groningen en omstreken 3              Centraal en Westelijk Groningen
# 596 Groningen en omstreken 2              Noord-Groningen-Eemsmond

# %% [markdown]
# ## Assignment 2e
#
# Create a map of Catholic and Protestant schools in the Netherlands

# %%
 AddMapLayer(MapPlot(), map_municipal) %>%
    AddPointsLayer(school_loc)
# Out:
# plot without title

# %% [markdown]
# End of notebook
